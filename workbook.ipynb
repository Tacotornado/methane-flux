# %%
import pandas as pd
import duckdb
import os
from datetime import datetime, timedelta
from tqdm import tqdm

# %%
con = duckdb.connect(database='dataset/JAAR_DB.duckdb', read_only=True)

# %% [markdown]
# Exploring the database

# %%
fetch_info = """
SELECT *
FROM information_schema.tables
"""

# %%
result = con.execute(fetch_info).fetchall()
print(result)

# %%
fetch_info = """
SELECT *
FROM JAAR_raw
ORDER BY ChamberID, TIMESTAMP
"""

# %%
result = con.execute(fetch_info).df()
print(result)

# %%
print(result.info())

# %%
result.to_csv('JAAR_raw.csv', index=False)

# %%
fetch_info = """
SELECT ChamberID, COUNT(*) as count
FROM JAAR_raw
GROUP BY ChamberID
ORDER BY ChamberID
"""

# %%
result = con.execute(fetch_info).df()
print(result)

# %% [markdown]
# Extracting important timestamps

# %%
fetch_info = """
WITH active_sessions AS (
    SELECT
        ChamberID,
        TIMESTAMP,
        ChamberStatus,
        LAG(ChamberStatus) OVER (PARTITION BY ChamberID ORDER BY TIMESTAMP) AS prev_status,
        LEAD(ChamberStatus) OVER (PARTITION BY ChamberID ORDER BY TIMESTAMP) AS next_status
    FROM JAAR_raw
    ORDER BY ChamberID, TIMESTAMP
),
session_start AS (
    SELECT
        ChamberID,
        TIMESTAMP AS start_time,
    FROM active_sessions
    WHERE ChamberStatus != 0 AND (prev_status = 0 OR prev_status IS NULL)
),
session_end AS (
    SELECT
        ChamberID,
        TIMESTAMP AS end_time,
    FROM active_sessions
    WHERE ChamberStatus != 0 AND (next_status = 0 OR next_status IS NULL)
)
SELECT
    s.ChamberID,
    s.start_time,
    e.end_time,
    DATEDIFF('second', CAST(s.start_time AS TIMESTAMP), CAST(e.end_time AS TIMESTAMP)) AS duration_seconds
FROM session_start s
JOIN LATERAL (
    SELECT e.end_time
    FROM session_end e
    WHERE e.ChamberID = s.ChamberID AND e.end_time > s.start_time
    ORDER BY e.end_time
    LIMIT 1
) e ON true
ORDER BY s.ChamberID, s.start_time
"""

# %%
all_active_sessions = con.execute(fetch_info).df()
print(all_active_sessions)
# Out:
#        ChamberID           start_time             end_time  duration_seconds
# 0            1.0  2025-03-04 00:34:47  2025-03-04 00:39:55               308
# 1            1.0  2025-03-04 01:34:47  2025-03-04 01:39:55               308
# 2            1.0  2025-03-04 02:34:47  2025-03-04 02:39:55               308
# 3            1.0  2025-03-04 03:34:47  2025-03-04 03:39:55               308
# 4            1.0  2025-03-04 04:34:47  2025-03-04 04:39:55               308
# ...          ...                  ...                  ...               ...
# 24189        9.0  2025-06-23 19:32:43  2025-06-23 19:37:51               308
# 24190        9.0  2025-06-23 20:32:43  2025-06-23 20:37:51               308
# 24191        9.0  2025-06-23 21:32:43  2025-06-23 21:37:51               308
# 24192        9.0  2025-06-23 22:32:43  2025-06-23 22:37:51               308
# 24193        9.0  2025-06-23 23:32:43  2025-06-23 23:37:51               308
#
# [24194 rows x 4 columns]

# %%
all_active_sessions['ChamberID'].value_counts()
# Out:
# ChamberID
# 1.0    2689
# 6.0    2689
# 2.0    2688
# 4.0    2688
# 3.0    2688
# 5.0    2688
# 7.0    2688
# 8.0    2688
# 9.0    2688
# Name: count, dtype: int64

# %%
len(all_active_sessions)

# %% [markdown]
# Extracting the actual data based on the timestamps

# %%
result_dir = 'result'

# %%
session_count = 0
idx = 0
while(idx < len(all_active_sessions)):
    session_count += 1
    
    row_1 = all_active_sessions.iloc[idx]
    row_2 = all_active_sessions.iloc[idx + 1] if idx + 1 < len(all_active_sessions) else None

    #Extract data from the first row
    chamber_id = row_1['ChamberID']
    start_time = row_1['start_time']
    end_time = row_1['end_time']
    duration_seconds = row_1['duration_seconds']
    
    start_time_dt = datetime.fromisoformat(str(start_time))
    end_time_dt = datetime.fromisoformat(str(end_time))

    buffer_start = start_time_dt - timedelta(seconds=5)
    buffer_end = end_time_dt + (timedelta(seconds=5) if row_2 is None else timedelta(seconds=0))

    print(f"Processing ChamberID {chamber_id}, session {session_count}")
    print(f"Period: {str(start_time)} to {str(end_time)} ({duration_seconds:.0f}seconds)")

    data_query = f"""
    SELECT
        TIMESTAMP,
        CH4,
        ChamberStatus,
        ChamberID,
        ChamberTC,
    FROM JAAR_raw
    WHERE ChamberID = '{chamber_id}'
    AND TIMESTAMP >= '{buffer_start}'
    AND TIMESTAMP <= '{buffer_end}'
    ORDER BY TIMESTAMP
    """

    df = con.execute(data_query).df()

    idx += 1
    
    #Extrac data from the second row if it exists
    if row_2 is not None:
        chamber_id_next = row_2['ChamberID']
        
        if chamber_id_next != chamber_id:
            continue

        start_time_next = row_2['start_time']
        end_time_next = row_2['end_time']
        duration_seconds_next = row_2['duration_seconds']

        start_time_next_dt = datetime.fromisoformat(str(start_time_next))
        end_time_next_dt = datetime.fromisoformat(str(end_time_next))

        buffer_start_next = start_time_next_dt - timedelta(seconds=0)
        buffer_end_next = end_time_next_dt + timedelta(seconds=5)

        print(f"Merging with next session period: {str(buffer_start_next)} to {str(buffer_end_next)} ({duration_seconds_next:.0f}seconds)")

        data_query = f"""
        SELECT
            TIMESTAMP,
            CH4,
            ChamberStatus,
            ChamberID,
            ChamberTC,
        FROM JAAR_raw
        WHERE ChamberID = '{chamber_id_next}'
        AND TIMESTAMP >= '{buffer_start_next}'
        AND TIMESTAMP <= '{buffer_end_next}'
        ORDER BY TIMESTAMP
        """

        df_next = con.execute(data_query).df()

        #Merge the two dataframes
        df = pd.concat([df, df_next], ignore_index=True)

        idx += 1
    
    #Save the dataframe to a CSV file
    if len(df) > 0:
        session_key = f"Chamber_{int(chamber_id)}_Session_{session_count}"
        csv_filename = os.path.join(result_dir, f"{session_key}.csv")
        df.to_csv(csv_filename, index=False)
    else:
        print(f"No data found for ChamberID {chamber_id} in session {session_count}. Skipping...")

print(f"Total sessions processed: {session_count}")

# %%
print(df)

# %%
session_count = 0
segment_count = 0
idx = 0
time_sample = 400
dfs = []
_len = len(all_active_sessions)
pbar = tqdm(total=_len, desc="Processing session")
total_duration = 0
while(True):
    session_count += 1
    row = all_active_sessions.iloc[idx]
    next_row = all_active_sessions.iloc[idx+1] if idx < _len-1 else None

    #Extract data from the first row
    chamber_id = row['ChamberID']
    start_time = row['start_time']
    end_time = row['end_time']
    duration_seconds = row['duration_seconds']
    
    start_time_dt = datetime.fromisoformat(str(start_time))
    end_time_dt = datetime.fromisoformat(str(end_time))

    #print(f"Processing ChamberID {chamber_id}, session {session_count}")
    #print(f"Period: {str(start_time)} to {str(end_time)} ({duration_seconds:.0f}seconds)")

    data_query = f"""
    SELECT
        TIMESTAMP,
        CH4,
        ChamberStatus,
        ChamberID,
        ChamberTC,
    FROM JAAR_raw
    WHERE ChamberID = '{chamber_id}'
    AND TIMESTAMP >= '{start_time_dt}'
    AND TIMESTAMP <= '{end_time_dt}'
    ORDER BY TIMESTAMP
    """

    df = con.execute(data_query).df()

    # Update some parameter
    idx += 1
    total_duration += duration_seconds

    # Check if the recent queried df exceed the time sample, if yes split it then append else just append
    if (total_duration >= time_sample):
        time_diff = total_duration - time_sample + 1
        idx_sep = duration_seconds - time_diff
        df_1, df_2 = df.iloc[:idx_sep], df.iloc[idx_sep:]
        dfs.append(df_1)
        dfs.append(df_2)
    else:
        dfs.append(df)

    # Check whether the total duration has exceed the time sample or not
    # Check whether the index has exceed all active sessions
    all_session_processed = (idx >= _len)
    different_id = (row['ChamberID'] != next_row['ChamberID']) if next_row is not None else True
    time_exceed = (total_duration > time_sample)
    time_equal = (total_duration == time_sample)
    if(time_exceed or time_equal or different_id or all_session_processed):
        segment_count += 1
        if time_exceed and not different_id:
            # Combine until dfs[:-1]
            combined_df = pd.concat(dfs[:-1], ignore_index=True)

            # Leave the last element in the dfs
            dfs[:] = [dfs[-1]]

            # Reset the total duration to be the residue time
            total_duration = time_diff
        else:
            # Combine all dfs
            combined_df = pd.concat(dfs, ignore_index=True)

            # Reset the list
            dfs[:] = []

            # Reset the total duration to be 0
            total_duration = 0

        #Save the dataframe to a CSV file
        if len(combined_df) > 0:
            session_key = f"Chamber_{int(chamber_id)}_Segment_{segment_count}"
            csv_filename = os.path.join(result_dir, f"{session_key}.csv")
            combined_df.to_csv(csv_filename, index=False)
        else:
            print(f"No data found for ChamberID {chamber_id} in session {session_count}. Skipping...")
        
        # Break if all session has been processed
        if(all_session_processed):
            break

print(f"Total sessions processed: {session_count}")
# Out:
# Processing ChamberID 1.0, session 1
# Period: 2025-03-04 00:34:47 to 2025-03-04 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 2
# Period: 2025-03-04 01:34:47 to 2025-03-04 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 3
# Period: 2025-03-04 02:34:47 to 2025-03-04 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 4
# Period: 2025-03-04 03:34:47 to 2025-03-04 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 5
# Period: 2025-03-04 04:34:47 to 2025-03-04 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 6
# Period: 2025-03-04 05:34:47 to 2025-03-04 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 7
# Period: 2025-03-04 06:34:47 to 2025-03-04 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 8
# Period: 2025-03-04 07:34:47 to 2025-03-04 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 9
# Period: 2025-03-04 08:34:47 to 2025-03-04 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 10
# Period: 2025-03-04 09:34:47 to 2025-03-04 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 11
# Period: 2025-03-04 10:34:47 to 2025-03-04 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 12
# Period: 2025-03-04 11:34:47 to 2025-03-04 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 13
# Period: 2025-03-04 12:34:47 to 2025-03-04 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 14
# Period: 2025-03-04 13:34:47 to 2025-03-04 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 15
# Period: 2025-03-04 14:34:47 to 2025-03-04 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 16
# Period: 2025-03-04 15:34:47 to 2025-03-04 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 17
# Period: 2025-03-04 16:34:47 to 2025-03-04 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 18
# Period: 2025-03-04 17:34:47 to 2025-03-04 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 19
# Period: 2025-03-04 18:34:47 to 2025-03-04 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 20
# Period: 2025-03-04 19:34:47 to 2025-03-04 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 21
# Period: 2025-03-04 20:34:47 to 2025-03-04 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 22
# Period: 2025-03-04 21:34:47 to 2025-03-04 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 23
# Period: 2025-03-04 22:34:47 to 2025-03-04 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 24
# Period: 2025-03-04 23:34:47 to 2025-03-04 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 25
# Period: 2025-03-05 00:34:47 to 2025-03-05 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 26
# Period: 2025-03-05 01:34:47 to 2025-03-05 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 27
# Period: 2025-03-05 02:34:47 to 2025-03-05 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 28
# Period: 2025-03-05 03:34:47 to 2025-03-05 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 29
# Period: 2025-03-05 04:34:47 to 2025-03-05 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 30
# Period: 2025-03-05 05:34:47 to 2025-03-05 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 31
# Period: 2025-03-05 06:34:47 to 2025-03-05 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 32
# Period: 2025-03-05 07:34:47 to 2025-03-05 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 33
# Period: 2025-03-05 08:34:47 to 2025-03-05 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 34
# Period: 2025-03-05 09:34:47 to 2025-03-05 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 35
# Period: 2025-03-05 10:34:47 to 2025-03-05 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 36
# Period: 2025-03-05 11:34:47 to 2025-03-05 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 37
# Period: 2025-03-05 12:34:47 to 2025-03-05 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 38
# Period: 2025-03-05 13:34:47 to 2025-03-05 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 39
# Period: 2025-03-05 14:34:47 to 2025-03-05 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 40
# Period: 2025-03-05 15:34:47 to 2025-03-05 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 41
# Period: 2025-03-05 16:34:47 to 2025-03-05 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 42
# Period: 2025-03-05 17:34:47 to 2025-03-05 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 43
# Period: 2025-03-05 18:34:47 to 2025-03-05 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 44
# Period: 2025-03-05 19:34:47 to 2025-03-05 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 45
# Period: 2025-03-05 20:34:47 to 2025-03-05 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 46
# Period: 2025-03-05 21:34:47 to 2025-03-05 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 47
# Period: 2025-03-05 22:34:47 to 2025-03-05 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 48
# Period: 2025-03-05 23:34:47 to 2025-03-05 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 49
# Period: 2025-03-06 00:34:47 to 2025-03-06 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 50
# Period: 2025-03-06 01:34:47 to 2025-03-06 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 51
# Period: 2025-03-06 02:34:47 to 2025-03-06 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 52
# Period: 2025-03-06 03:34:47 to 2025-03-06 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 53
# Period: 2025-03-06 04:34:47 to 2025-03-06 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 54
# Period: 2025-03-06 05:34:47 to 2025-03-06 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 55
# Period: 2025-03-06 06:34:47 to 2025-03-06 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 56
# Period: 2025-03-06 07:34:47 to 2025-03-06 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 57
# Period: 2025-03-06 08:34:47 to 2025-03-06 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 58
# Period: 2025-03-06 09:34:47 to 2025-03-06 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 59
# Period: 2025-03-06 10:34:47 to 2025-03-06 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 60
# Period: 2025-03-06 11:34:47 to 2025-03-06 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 61
# Period: 2025-03-06 12:34:47 to 2025-03-06 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 62
# Period: 2025-03-06 13:34:47 to 2025-03-06 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 63
# Period: 2025-03-06 14:34:47 to 2025-03-06 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 64
# Period: 2025-03-06 15:34:47 to 2025-03-06 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 65
# Period: 2025-03-06 16:34:47 to 2025-03-06 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 66
# Period: 2025-03-06 17:34:47 to 2025-03-06 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 67
# Period: 2025-03-06 18:34:47 to 2025-03-06 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 68
# Period: 2025-03-06 19:34:47 to 2025-03-06 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 69
# Period: 2025-03-06 20:34:47 to 2025-03-06 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 70
# Period: 2025-03-06 21:34:47 to 2025-03-06 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 71
# Period: 2025-03-06 22:34:47 to 2025-03-06 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 72
# Period: 2025-03-06 23:34:47 to 2025-03-06 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 73
# Period: 2025-03-07 00:34:47 to 2025-03-07 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 74
# Period: 2025-03-07 01:34:47 to 2025-03-07 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 75
# Period: 2025-03-07 02:34:47 to 2025-03-07 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 76
# Period: 2025-03-07 03:34:47 to 2025-03-07 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 77
# Period: 2025-03-07 04:34:47 to 2025-03-07 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 78
# Period: 2025-03-07 05:34:47 to 2025-03-07 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 79
# Period: 2025-03-07 06:34:47 to 2025-03-07 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 80
# Period: 2025-03-07 07:34:47 to 2025-03-07 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 81
# Period: 2025-03-07 08:34:47 to 2025-03-07 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 82
# Period: 2025-03-07 09:34:47 to 2025-03-07 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 83
# Period: 2025-03-07 10:34:47 to 2025-03-07 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 84
# Period: 2025-03-07 11:34:47 to 2025-03-07 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 85
# Period: 2025-03-07 12:34:47 to 2025-03-07 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 86
# Period: 2025-03-07 13:34:47 to 2025-03-07 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 87
# Period: 2025-03-07 14:34:47 to 2025-03-07 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 88
# Period: 2025-03-07 15:34:47 to 2025-03-07 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 89
# Period: 2025-03-07 16:34:47 to 2025-03-07 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 90
# Period: 2025-03-07 17:34:47 to 2025-03-07 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 91
# Period: 2025-03-07 18:34:47 to 2025-03-07 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 92
# Period: 2025-03-07 19:34:47 to 2025-03-07 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 93
# Period: 2025-03-07 20:34:47 to 2025-03-07 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 94
# Period: 2025-03-07 21:34:47 to 2025-03-07 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 95
# Period: 2025-03-07 22:34:47 to 2025-03-07 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 96
# Period: 2025-03-07 23:34:47 to 2025-03-07 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 97
# Period: 2025-03-08 00:34:47 to 2025-03-08 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 98
# Period: 2025-03-08 01:34:47 to 2025-03-08 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 99
# Period: 2025-03-08 02:34:47 to 2025-03-08 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 100
# Period: 2025-03-08 03:34:47 to 2025-03-08 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 101
# Period: 2025-03-08 04:34:47 to 2025-03-08 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 102
# Period: 2025-03-08 05:34:47 to 2025-03-08 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 103
# Period: 2025-03-08 06:34:47 to 2025-03-08 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 104
# Period: 2025-03-08 07:34:47 to 2025-03-08 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 105
# Period: 2025-03-08 08:34:47 to 2025-03-08 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 106
# Period: 2025-03-08 09:34:47 to 2025-03-08 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 107
# Period: 2025-03-08 10:34:47 to 2025-03-08 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 108
# Period: 2025-03-08 11:34:47 to 2025-03-08 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 109
# Period: 2025-03-08 12:34:47 to 2025-03-08 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 110
# Period: 2025-03-08 13:34:47 to 2025-03-08 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 111
# Period: 2025-03-08 14:34:47 to 2025-03-08 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 112
# Period: 2025-03-08 15:34:47 to 2025-03-08 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 113
# Period: 2025-03-08 16:34:47 to 2025-03-08 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 114
# Period: 2025-03-08 17:34:47 to 2025-03-08 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 115
# Period: 2025-03-08 18:34:47 to 2025-03-08 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 116
# Period: 2025-03-08 19:34:47 to 2025-03-08 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 117
# Period: 2025-03-08 20:34:47 to 2025-03-08 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 118
# Period: 2025-03-08 21:34:47 to 2025-03-08 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 119
# Period: 2025-03-08 22:34:47 to 2025-03-08 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 120
# Period: 2025-03-08 23:34:47 to 2025-03-08 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 121
# Period: 2025-03-09 00:34:47 to 2025-03-09 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 122
# Period: 2025-03-09 01:34:47 to 2025-03-09 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 123
# Period: 2025-03-09 02:34:47 to 2025-03-09 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 124
# Period: 2025-03-09 03:34:47 to 2025-03-09 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 125
# Period: 2025-03-09 04:34:47 to 2025-03-09 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 126
# Period: 2025-03-09 05:34:47 to 2025-03-09 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 127
# Period: 2025-03-09 06:34:47 to 2025-03-09 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 128
# Period: 2025-03-09 07:34:47 to 2025-03-09 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 129
# Period: 2025-03-09 08:34:47 to 2025-03-09 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 130
# Period: 2025-03-09 09:34:47 to 2025-03-09 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 131
# Period: 2025-03-09 10:34:47 to 2025-03-09 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 132
# Period: 2025-03-09 11:34:47 to 2025-03-09 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 133
# Period: 2025-03-09 12:34:47 to 2025-03-09 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 134
# Period: 2025-03-09 13:34:47 to 2025-03-09 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 135
# Period: 2025-03-09 14:34:47 to 2025-03-09 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 136
# Period: 2025-03-09 15:34:47 to 2025-03-09 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 137
# Period: 2025-03-09 16:34:47 to 2025-03-09 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 138
# Period: 2025-03-09 17:34:47 to 2025-03-09 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 139
# Period: 2025-03-09 18:34:47 to 2025-03-09 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 140
# Period: 2025-03-09 19:34:47 to 2025-03-09 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 141
# Period: 2025-03-09 20:34:47 to 2025-03-09 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 142
# Period: 2025-03-09 21:34:47 to 2025-03-09 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 143
# Period: 2025-03-09 22:34:47 to 2025-03-09 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 144
# Period: 2025-03-09 23:34:47 to 2025-03-09 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 145
# Period: 2025-03-10 00:34:47 to 2025-03-10 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 146
# Period: 2025-03-10 01:34:47 to 2025-03-10 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 147
# Period: 2025-03-10 02:34:47 to 2025-03-10 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 148
# Period: 2025-03-10 03:34:47 to 2025-03-10 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 149
# Period: 2025-03-10 04:34:47 to 2025-03-10 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 150
# Period: 2025-03-10 05:34:47 to 2025-03-10 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 151
# Period: 2025-03-10 06:34:47 to 2025-03-10 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 152
# Period: 2025-03-10 07:34:47 to 2025-03-10 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 153
# Period: 2025-03-10 08:34:47 to 2025-03-10 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 154
# Period: 2025-03-10 09:34:47 to 2025-03-10 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 155
# Period: 2025-03-10 10:34:47 to 2025-03-10 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 156
# Period: 2025-03-10 11:34:47 to 2025-03-10 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 157
# Period: 2025-03-10 12:34:47 to 2025-03-10 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 158
# Period: 2025-03-10 13:34:47 to 2025-03-10 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 159
# Period: 2025-03-10 14:34:47 to 2025-03-10 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 160
# Period: 2025-03-10 15:34:47 to 2025-03-10 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 161
# Period: 2025-03-10 16:34:47 to 2025-03-10 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 162
# Period: 2025-03-10 17:34:47 to 2025-03-10 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 163
# Period: 2025-03-10 18:34:47 to 2025-03-10 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 164
# Period: 2025-03-10 19:34:47 to 2025-03-10 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 165
# Period: 2025-03-10 20:34:47 to 2025-03-10 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 166
# Period: 2025-03-10 21:34:47 to 2025-03-10 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 167
# Period: 2025-03-10 22:34:47 to 2025-03-10 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 168
# Period: 2025-03-10 23:34:47 to 2025-03-10 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 169
# Period: 2025-03-11 00:34:47 to 2025-03-11 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 170
# Period: 2025-03-11 01:34:47 to 2025-03-11 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 171
# Period: 2025-03-11 02:34:47 to 2025-03-11 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 172
# Period: 2025-03-11 03:34:47 to 2025-03-11 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 173
# Period: 2025-03-11 04:34:47 to 2025-03-11 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 174
# Period: 2025-03-11 05:34:47 to 2025-03-11 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 175
# Period: 2025-03-11 06:34:47 to 2025-03-11 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 176
# Period: 2025-03-11 07:34:47 to 2025-03-11 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 177
# Period: 2025-03-11 08:34:47 to 2025-03-11 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 178
# Period: 2025-03-11 09:34:47 to 2025-03-11 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 179
# Period: 2025-03-11 10:34:47 to 2025-03-11 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 180
# Period: 2025-03-11 11:34:47 to 2025-03-11 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 181
# Period: 2025-03-11 12:34:47 to 2025-03-11 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 182
# Period: 2025-03-11 13:34:47 to 2025-03-11 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 183
# Period: 2025-03-11 14:34:47 to 2025-03-11 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 184
# Period: 2025-03-11 15:34:47 to 2025-03-11 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 185
# Period: 2025-03-11 16:34:47 to 2025-03-11 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 186
# Period: 2025-03-11 17:34:47 to 2025-03-11 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 187
# Period: 2025-03-11 18:34:47 to 2025-03-11 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 188
# Period: 2025-03-11 19:34:47 to 2025-03-11 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 189
# Period: 2025-03-11 20:34:47 to 2025-03-11 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 190
# Period: 2025-03-11 21:34:47 to 2025-03-11 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 191
# Period: 2025-03-11 22:34:47 to 2025-03-11 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 192
# Period: 2025-03-11 23:34:47 to 2025-03-11 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 193
# Period: 2025-03-12 00:34:47 to 2025-03-12 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 194
# Period: 2025-03-12 01:34:47 to 2025-03-12 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 195
# Period: 2025-03-12 02:34:47 to 2025-03-12 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 196
# Period: 2025-03-12 03:34:47 to 2025-03-12 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 197
# Period: 2025-03-12 04:34:47 to 2025-03-12 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 198
# Period: 2025-03-12 05:34:47 to 2025-03-12 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 199
# Period: 2025-03-12 06:34:47 to 2025-03-12 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 200
# Period: 2025-03-12 07:34:47 to 2025-03-12 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 201
# Period: 2025-03-12 08:34:47 to 2025-03-12 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 202
# Period: 2025-03-12 09:34:47 to 2025-03-12 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 203
# Period: 2025-03-12 10:34:47 to 2025-03-12 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 204
# Period: 2025-03-12 11:34:47 to 2025-03-12 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 205
# Period: 2025-03-12 12:34:47 to 2025-03-12 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 206
# Period: 2025-03-12 13:34:47 to 2025-03-12 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 207
# Period: 2025-03-12 14:34:47 to 2025-03-12 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 208
# Period: 2025-03-12 15:34:47 to 2025-03-12 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 209
# Period: 2025-03-12 16:34:47 to 2025-03-12 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 210
# Period: 2025-03-12 17:34:47 to 2025-03-12 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 211
# Period: 2025-03-12 18:34:47 to 2025-03-12 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 212
# Period: 2025-03-12 19:34:47 to 2025-03-12 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 213
# Period: 2025-03-12 20:34:47 to 2025-03-12 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 214
# Period: 2025-03-12 21:34:47 to 2025-03-12 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 215
# Period: 2025-03-12 22:34:47 to 2025-03-12 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 216
# Period: 2025-03-12 23:34:47 to 2025-03-12 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 217
# Period: 2025-03-13 00:34:47 to 2025-03-13 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 218
# Period: 2025-03-13 01:34:47 to 2025-03-13 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 219
# Period: 2025-03-13 02:34:47 to 2025-03-13 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 220
# Period: 2025-03-13 03:34:47 to 2025-03-13 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 221
# Period: 2025-03-13 04:34:47 to 2025-03-13 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 222
# Period: 2025-03-13 05:34:47 to 2025-03-13 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 223
# Period: 2025-03-13 06:34:47 to 2025-03-13 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 224
# Period: 2025-03-13 07:34:47 to 2025-03-13 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 225
# Period: 2025-03-13 08:34:47 to 2025-03-13 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 226
# Period: 2025-03-13 09:34:47 to 2025-03-13 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 227
# Period: 2025-03-13 10:34:47 to 2025-03-13 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 228
# Period: 2025-03-13 11:34:47 to 2025-03-13 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 229
# Period: 2025-03-13 12:34:47 to 2025-03-13 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 230
# Period: 2025-03-13 13:34:47 to 2025-03-13 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 231
# Period: 2025-03-13 14:34:47 to 2025-03-13 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 232
# Period: 2025-03-13 15:34:47 to 2025-03-13 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 233
# Period: 2025-03-13 16:34:47 to 2025-03-13 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 234
# Period: 2025-03-13 17:34:47 to 2025-03-13 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 235
# Period: 2025-03-13 18:34:47 to 2025-03-13 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 236
# Period: 2025-03-13 19:34:47 to 2025-03-13 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 237
# Period: 2025-03-13 20:34:47 to 2025-03-13 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 238
# Period: 2025-03-13 21:34:47 to 2025-03-13 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 239
# Period: 2025-03-13 22:34:47 to 2025-03-13 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 240
# Period: 2025-03-13 23:34:47 to 2025-03-13 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 241
# Period: 2025-03-14 00:34:47 to 2025-03-14 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 242
# Period: 2025-03-14 01:34:47 to 2025-03-14 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 243
# Period: 2025-03-14 02:34:47 to 2025-03-14 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 244
# Period: 2025-03-14 03:34:47 to 2025-03-14 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 245
# Period: 2025-03-14 04:34:47 to 2025-03-14 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 246
# Period: 2025-03-14 05:34:47 to 2025-03-14 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 247
# Period: 2025-03-14 06:34:47 to 2025-03-14 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 248
# Period: 2025-03-14 07:34:47 to 2025-03-14 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 249
# Period: 2025-03-14 08:34:47 to 2025-03-14 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 250
# Period: 2025-03-14 09:34:47 to 2025-03-14 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 251
# Period: 2025-03-14 10:34:47 to 2025-03-14 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 252
# Period: 2025-03-14 11:34:47 to 2025-03-14 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 253
# Period: 2025-03-14 12:34:47 to 2025-03-14 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 254
# Period: 2025-03-14 13:34:47 to 2025-03-14 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 255
# Period: 2025-03-14 14:34:47 to 2025-03-14 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 256
# Period: 2025-03-14 15:34:47 to 2025-03-14 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 257
# Period: 2025-03-14 16:34:47 to 2025-03-14 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 258
# Period: 2025-03-14 17:34:47 to 2025-03-14 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 259
# Period: 2025-03-14 18:34:47 to 2025-03-14 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 260
# Period: 2025-03-14 19:34:47 to 2025-03-14 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 261
# Period: 2025-03-14 20:34:47 to 2025-03-14 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 262
# Period: 2025-03-14 21:34:47 to 2025-03-14 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 263
# Period: 2025-03-14 22:34:47 to 2025-03-14 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 264
# Period: 2025-03-14 23:34:47 to 2025-03-14 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 265
# Period: 2025-03-15 00:34:47 to 2025-03-15 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 266
# Period: 2025-03-15 01:34:47 to 2025-03-15 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 267
# Period: 2025-03-15 02:34:47 to 2025-03-15 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 268
# Period: 2025-03-15 03:34:47 to 2025-03-15 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 269
# Period: 2025-03-15 04:34:47 to 2025-03-15 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 270
# Period: 2025-03-15 05:34:47 to 2025-03-15 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 271
# Period: 2025-03-15 06:34:47 to 2025-03-15 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 272
# Period: 2025-03-15 07:34:47 to 2025-03-15 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 273
# Period: 2025-03-15 08:34:47 to 2025-03-15 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 274
# Period: 2025-03-15 09:34:47 to 2025-03-15 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 275
# Period: 2025-03-15 10:34:47 to 2025-03-15 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 276
# Period: 2025-03-15 11:34:47 to 2025-03-15 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 277
# Period: 2025-03-15 12:34:47 to 2025-03-15 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 278
# Period: 2025-03-15 13:34:47 to 2025-03-15 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 279
# Period: 2025-03-15 14:34:47 to 2025-03-15 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 280
# Period: 2025-03-15 15:34:47 to 2025-03-15 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 281
# Period: 2025-03-15 16:34:47 to 2025-03-15 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 282
# Period: 2025-03-15 17:34:47 to 2025-03-15 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 283
# Period: 2025-03-15 18:34:47 to 2025-03-15 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 284
# Period: 2025-03-15 19:34:47 to 2025-03-15 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 285
# Period: 2025-03-15 20:34:47 to 2025-03-15 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 286
# Period: 2025-03-15 21:34:47 to 2025-03-15 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 287
# Period: 2025-03-15 22:34:47 to 2025-03-15 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 288
# Period: 2025-03-15 23:34:47 to 2025-03-15 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 289
# Period: 2025-03-16 00:34:47 to 2025-03-16 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 290
# Period: 2025-03-16 01:34:47 to 2025-03-16 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 291
# Period: 2025-03-16 02:34:47 to 2025-03-16 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 292
# Period: 2025-03-16 03:34:47 to 2025-03-16 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 293
# Period: 2025-03-16 04:34:47 to 2025-03-16 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 294
# Period: 2025-03-16 05:34:47 to 2025-03-16 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 295
# Period: 2025-03-16 06:34:47 to 2025-03-16 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 296
# Period: 2025-03-16 07:34:47 to 2025-03-16 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 297
# Period: 2025-03-16 08:34:47 to 2025-03-16 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 298
# Period: 2025-03-16 09:34:47 to 2025-03-16 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 299
# Period: 2025-03-16 10:34:47 to 2025-03-16 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 300
# Period: 2025-03-16 11:34:47 to 2025-03-16 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 301
# Period: 2025-03-16 12:34:47 to 2025-03-16 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 302
# Period: 2025-03-16 13:34:47 to 2025-03-16 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 303
# Period: 2025-03-16 14:34:47 to 2025-03-16 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 304
# Period: 2025-03-16 15:34:47 to 2025-03-16 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 305
# Period: 2025-03-16 16:34:47 to 2025-03-16 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 306
# Period: 2025-03-16 17:34:47 to 2025-03-16 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 307
# Period: 2025-03-16 18:34:47 to 2025-03-16 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 308
# Period: 2025-03-16 19:34:47 to 2025-03-16 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 309
# Period: 2025-03-16 20:34:47 to 2025-03-16 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 310
# Period: 2025-03-16 21:34:47 to 2025-03-16 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 311
# Period: 2025-03-16 22:34:47 to 2025-03-16 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 312
# Period: 2025-03-16 23:34:47 to 2025-03-16 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 313
# Period: 2025-03-17 00:34:47 to 2025-03-17 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 314
# Period: 2025-03-17 01:34:47 to 2025-03-17 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 315
# Period: 2025-03-17 02:34:47 to 2025-03-17 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 316
# Period: 2025-03-17 03:34:47 to 2025-03-17 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 317
# Period: 2025-03-17 04:34:47 to 2025-03-17 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 318
# Period: 2025-03-17 05:34:47 to 2025-03-17 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 319
# Period: 2025-03-17 06:34:47 to 2025-03-17 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 320
# Period: 2025-03-17 07:34:47 to 2025-03-17 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 321
# Period: 2025-03-17 08:34:47 to 2025-03-17 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 322
# Period: 2025-03-17 09:34:47 to 2025-03-17 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 323
# Period: 2025-03-17 10:34:47 to 2025-03-17 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 324
# Period: 2025-03-17 11:34:47 to 2025-03-17 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 325
# Period: 2025-03-17 12:34:47 to 2025-03-17 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 326
# Period: 2025-03-17 13:34:47 to 2025-03-17 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 327
# Period: 2025-03-17 14:34:47 to 2025-03-17 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 328
# Period: 2025-03-17 15:34:47 to 2025-03-17 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 329
# Period: 2025-03-17 16:34:47 to 2025-03-17 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 330
# Period: 2025-03-17 17:34:47 to 2025-03-17 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 331
# Period: 2025-03-17 18:34:47 to 2025-03-17 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 332
# Period: 2025-03-17 19:34:47 to 2025-03-17 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 333
# Period: 2025-03-17 20:34:47 to 2025-03-17 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 334
# Period: 2025-03-17 21:34:47 to 2025-03-17 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 335
# Period: 2025-03-17 22:34:47 to 2025-03-17 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 336
# Period: 2025-03-17 23:34:47 to 2025-03-17 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 337
# Period: 2025-03-18 00:34:47 to 2025-03-18 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 338
# Period: 2025-03-18 01:34:47 to 2025-03-18 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 339
# Period: 2025-03-18 02:34:47 to 2025-03-18 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 340
# Period: 2025-03-18 03:34:47 to 2025-03-18 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 341
# Period: 2025-03-18 04:34:47 to 2025-03-18 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 342
# Period: 2025-03-18 05:34:47 to 2025-03-18 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 343
# Period: 2025-03-18 06:34:47 to 2025-03-18 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 344
# Period: 2025-03-18 07:34:47 to 2025-03-18 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 345
# Period: 2025-03-18 08:34:47 to 2025-03-18 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 346
# Period: 2025-03-18 09:34:47 to 2025-03-18 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 347
# Period: 2025-03-18 10:34:47 to 2025-03-18 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 348
# Period: 2025-03-18 11:34:47 to 2025-03-18 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 349
# Period: 2025-03-18 12:34:47 to 2025-03-18 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 350
# Period: 2025-03-18 13:34:47 to 2025-03-18 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 351
# Period: 2025-03-18 14:34:47 to 2025-03-18 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 352
# Period: 2025-03-18 15:34:47 to 2025-03-18 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 353
# Period: 2025-03-18 16:34:47 to 2025-03-18 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 354
# Period: 2025-03-18 17:34:47 to 2025-03-18 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 355
# Period: 2025-03-18 18:34:47 to 2025-03-18 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 356
# Period: 2025-03-18 19:34:47 to 2025-03-18 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 357
# Period: 2025-03-18 20:34:47 to 2025-03-18 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 358
# Period: 2025-03-18 21:34:47 to 2025-03-18 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 359
# Period: 2025-03-18 22:34:47 to 2025-03-18 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 360
# Period: 2025-03-18 23:34:47 to 2025-03-18 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 361
# Period: 2025-03-19 00:34:47 to 2025-03-19 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 362
# Period: 2025-03-19 01:34:47 to 2025-03-19 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 363
# Period: 2025-03-19 02:34:47 to 2025-03-19 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 364
# Period: 2025-03-19 03:34:47 to 2025-03-19 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 365
# Period: 2025-03-19 04:34:47 to 2025-03-19 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 366
# Period: 2025-03-19 05:34:47 to 2025-03-19 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 367
# Period: 2025-03-19 06:34:47 to 2025-03-19 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 368
# Period: 2025-03-19 07:34:47 to 2025-03-19 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 369
# Period: 2025-03-19 08:34:47 to 2025-03-19 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 370
# Period: 2025-03-19 09:34:47 to 2025-03-19 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 371
# Period: 2025-03-19 10:34:47 to 2025-03-19 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 372
# Period: 2025-03-19 11:34:47 to 2025-03-19 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 373
# Period: 2025-03-19 12:34:47 to 2025-03-19 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 374
# Period: 2025-03-19 13:34:47 to 2025-03-19 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 375
# Period: 2025-03-19 14:34:47 to 2025-03-19 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 376
# Period: 2025-03-19 15:34:47 to 2025-03-19 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 377
# Period: 2025-03-19 16:34:47 to 2025-03-19 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 378
# Period: 2025-03-19 17:34:47 to 2025-03-19 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 379
# Period: 2025-03-19 18:34:47 to 2025-03-19 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 380
# Period: 2025-03-19 19:34:47 to 2025-03-19 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 381
# Period: 2025-03-19 20:34:47 to 2025-03-19 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 382
# Period: 2025-03-19 21:34:47 to 2025-03-19 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 383
# Period: 2025-03-19 22:34:47 to 2025-03-19 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 384
# Period: 2025-03-19 23:34:47 to 2025-03-19 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 385
# Period: 2025-03-20 00:34:47 to 2025-03-20 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 386
# Period: 2025-03-20 01:34:47 to 2025-03-20 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 387
# Period: 2025-03-20 02:34:47 to 2025-03-20 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 388
# Period: 2025-03-20 03:34:47 to 2025-03-20 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 389
# Period: 2025-03-20 04:34:47 to 2025-03-20 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 390
# Period: 2025-03-20 05:34:47 to 2025-03-20 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 391
# Period: 2025-03-20 06:34:47 to 2025-03-20 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 392
# Period: 2025-03-20 07:34:47 to 2025-03-20 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 393
# Period: 2025-03-20 08:34:47 to 2025-03-20 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 394
# Period: 2025-03-20 09:34:47 to 2025-03-20 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 395
# Period: 2025-03-20 10:34:47 to 2025-03-20 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 396
# Period: 2025-03-20 11:34:47 to 2025-03-20 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 397
# Period: 2025-03-20 12:34:47 to 2025-03-20 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 398
# Period: 2025-03-20 13:34:47 to 2025-03-20 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 399
# Period: 2025-03-20 14:34:47 to 2025-03-20 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 400
# Period: 2025-03-20 15:34:47 to 2025-03-20 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 401
# Period: 2025-03-20 16:34:47 to 2025-03-20 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 402
# Period: 2025-03-20 17:34:47 to 2025-03-20 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 403
# Period: 2025-03-20 18:34:47 to 2025-03-20 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 404
# Period: 2025-03-20 19:34:47 to 2025-03-20 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 405
# Period: 2025-03-20 20:34:47 to 2025-03-20 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 406
# Period: 2025-03-20 21:34:47 to 2025-03-20 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 407
# Period: 2025-03-20 22:34:47 to 2025-03-20 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 408
# Period: 2025-03-20 23:34:47 to 2025-03-20 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 409
# Period: 2025-03-21 00:34:47 to 2025-03-21 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 410
# Period: 2025-03-21 01:34:47 to 2025-03-21 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 411
# Period: 2025-03-21 02:34:47 to 2025-03-21 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 412
# Period: 2025-03-21 03:34:47 to 2025-03-21 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 413
# Period: 2025-03-21 04:34:47 to 2025-03-21 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 414
# Period: 2025-03-21 05:34:47 to 2025-03-21 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 415
# Period: 2025-03-21 06:34:47 to 2025-03-21 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 416
# Period: 2025-03-21 07:34:47 to 2025-03-21 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 417
# Period: 2025-03-21 08:34:47 to 2025-03-21 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 418
# Period: 2025-03-21 09:34:47 to 2025-03-21 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 419
# Period: 2025-03-21 10:34:47 to 2025-03-21 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 420
# Period: 2025-03-21 11:34:47 to 2025-03-21 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 421
# Period: 2025-03-21 12:34:47 to 2025-03-21 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 422
# Period: 2025-03-21 13:34:47 to 2025-03-21 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 423
# Period: 2025-03-21 14:34:47 to 2025-03-21 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 424
# Period: 2025-03-21 15:34:47 to 2025-03-21 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 425
# Period: 2025-03-21 16:34:47 to 2025-03-21 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 426
# Period: 2025-03-21 17:34:47 to 2025-03-21 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 427
# Period: 2025-03-21 18:34:47 to 2025-03-21 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 428
# Period: 2025-03-21 19:34:47 to 2025-03-21 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 429
# Period: 2025-03-21 20:34:47 to 2025-03-21 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 430
# Period: 2025-03-21 21:34:47 to 2025-03-21 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 431
# Period: 2025-03-21 22:34:47 to 2025-03-21 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 432
# Period: 2025-03-21 23:34:47 to 2025-03-21 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 433
# Period: 2025-03-22 00:34:47 to 2025-03-22 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 434
# Period: 2025-03-22 01:34:47 to 2025-03-22 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 435
# Period: 2025-03-22 02:34:47 to 2025-03-22 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 436
# Period: 2025-03-22 03:34:47 to 2025-03-22 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 437
# Period: 2025-03-22 04:34:47 to 2025-03-22 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 438
# Period: 2025-03-22 05:34:47 to 2025-03-22 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 439
# Period: 2025-03-22 06:34:47 to 2025-03-22 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 440
# Period: 2025-03-22 07:34:47 to 2025-03-22 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 441
# Period: 2025-03-22 08:34:47 to 2025-03-22 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 442
# Period: 2025-03-22 09:34:47 to 2025-03-22 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 443
# Period: 2025-03-22 10:34:47 to 2025-03-22 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 444
# Period: 2025-03-22 11:34:47 to 2025-03-22 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 445
# Period: 2025-03-22 12:34:47 to 2025-03-22 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 446
# Period: 2025-03-22 13:34:47 to 2025-03-22 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 447
# Period: 2025-03-22 14:34:47 to 2025-03-22 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 448
# Period: 2025-03-22 15:34:47 to 2025-03-22 15:39:55 (308seconds)
# Processing ChamberID 1.0, session 449
# Period: 2025-03-22 16:34:47 to 2025-03-22 16:39:55 (308seconds)
# Processing ChamberID 1.0, session 450
# Period: 2025-03-22 17:34:47 to 2025-03-22 17:39:55 (308seconds)
# Processing ChamberID 1.0, session 451
# Period: 2025-03-22 18:34:47 to 2025-03-22 18:39:55 (308seconds)
# Processing ChamberID 1.0, session 452
# Period: 2025-03-22 19:34:47 to 2025-03-22 19:39:55 (308seconds)
# Processing ChamberID 1.0, session 453
# Period: 2025-03-22 20:34:47 to 2025-03-22 20:39:55 (308seconds)
# Processing ChamberID 1.0, session 454
# Period: 2025-03-22 21:34:47 to 2025-03-22 21:39:55 (308seconds)
# Processing ChamberID 1.0, session 455
# Period: 2025-03-22 22:34:47 to 2025-03-22 22:39:55 (308seconds)
# Processing ChamberID 1.0, session 456
# Period: 2025-03-22 23:34:47 to 2025-03-22 23:39:55 (308seconds)
# Processing ChamberID 1.0, session 457
# Period: 2025-03-23 00:34:47 to 2025-03-23 00:39:55 (308seconds)
# Processing ChamberID 1.0, session 458
# Period: 2025-03-23 01:34:47 to 2025-03-23 01:39:55 (308seconds)
# Processing ChamberID 1.0, session 459
# Period: 2025-03-23 02:34:47 to 2025-03-23 02:39:55 (308seconds)
# Processing ChamberID 1.0, session 460
# Period: 2025-03-23 03:34:47 to 2025-03-23 03:39:55 (308seconds)
# Processing ChamberID 1.0, session 461
# Period: 2025-03-23 04:34:47 to 2025-03-23 04:39:55 (308seconds)
# Processing ChamberID 1.0, session 462
# Period: 2025-03-23 05:34:47 to 2025-03-23 05:39:55 (308seconds)
# Processing ChamberID 1.0, session 463
# Period: 2025-03-23 06:34:47 to 2025-03-23 06:39:55 (308seconds)
# Processing ChamberID 1.0, session 464
# Period: 2025-03-23 07:34:47 to 2025-03-23 07:39:55 (308seconds)
# Processing ChamberID 1.0, session 465
# Period: 2025-03-23 08:34:47 to 2025-03-23 08:39:55 (308seconds)
# Processing ChamberID 1.0, session 466
# Period: 2025-03-23 09:34:47 to 2025-03-23 09:39:55 (308seconds)
# Processing ChamberID 1.0, session 467
# Period: 2025-03-23 10:34:47 to 2025-03-23 10:39:55 (308seconds)
# Processing ChamberID 1.0, session 468
# Period: 2025-03-23 11:34:47 to 2025-03-23 11:39:55 (308seconds)
# Processing ChamberID 1.0, session 469
# Period: 2025-03-23 12:34:47 to 2025-03-23 12:39:55 (308seconds)
# Processing ChamberID 1.0, session 470
# Period: 2025-03-23 13:34:47 to 2025-03-23 13:39:55 (308seconds)
# Processing ChamberID 1.0, session 471
# Period: 2025-03-23 14:34:47 to 2025-03-23 14:39:55 (308seconds)
# Processing ChamberID 1.0, session 472
# ...
# Processing ChamberID 9.0, session 24042
# Period: 2025-06-17 15:32:45 to 2025-06-17 15:37:53 (308seconds)
# Processing ChamberID 9.0, session 24043
# Period: 2025-06-17 16:32:45 to 2025-06-17 16:37:53 (308seconds)
# Processing ChamberID 9.0, session 24044
# Period: 2025-06-17 17:32:45 to 2025-06-17 17:37:53 (308seconds)
# Processing ChamberID 9.0, session 24045
# Period: 2025-06-17 18:32:45 to 2025-06-17 18:37:53 (308seconds)
# Processing ChamberID 9.0, session 24046
# Period: 2025-06-17 19:32:45 to 2025-06-17 19:37:53 (308seconds)
# Processing ChamberID 9.0, session 24047
# Period: 2025-06-17 20:32:45 to 2025-06-17 20:37:53 (308seconds)
# Processing ChamberID 9.0, session 24048
# Period: 2025-06-17 21:32:45 to 2025-06-17 21:37:53 (308seconds)
# Processing ChamberID 9.0, session 24049
# Period: 2025-06-17 22:32:45 to 2025-06-17 22:37:53 (308seconds)
# Processing ChamberID 9.0, session 24050
# Period: 2025-06-17 23:32:45 to 2025-06-17 23:37:53 (308seconds)
# Processing ChamberID 9.0, session 24051
# Period: 2025-06-18 00:32:45 to 2025-06-18 00:37:53 (308seconds)
# Processing ChamberID 9.0, session 24052
# Period: 2025-06-18 01:32:45 to 2025-06-18 01:37:53 (308seconds)
# Processing ChamberID 9.0, session 24053
# Period: 2025-06-18 02:32:45 to 2025-06-18 02:37:53 (308seconds)
# Processing ChamberID 9.0, session 24054
# Period: 2025-06-18 03:32:45 to 2025-06-18 03:37:53 (308seconds)
# Processing ChamberID 9.0, session 24055
# Period: 2025-06-18 04:32:45 to 2025-06-18 04:37:53 (308seconds)
# Processing ChamberID 9.0, session 24056
# Period: 2025-06-18 05:32:45 to 2025-06-18 05:37:53 (308seconds)
# Processing ChamberID 9.0, session 24057
# Period: 2025-06-18 06:32:45 to 2025-06-18 06:37:53 (308seconds)
# Processing ChamberID 9.0, session 24058
# Period: 2025-06-18 07:32:45 to 2025-06-18 07:37:53 (308seconds)
# Processing ChamberID 9.0, session 24059
# Period: 2025-06-18 08:32:45 to 2025-06-18 08:37:53 (308seconds)
# Processing ChamberID 9.0, session 24060
# Period: 2025-06-18 09:32:45 to 2025-06-18 09:37:53 (308seconds)
# Processing ChamberID 9.0, session 24061
# Period: 2025-06-18 10:32:45 to 2025-06-18 10:37:53 (308seconds)
# Processing ChamberID 9.0, session 24062
# Period: 2025-06-18 11:32:45 to 2025-06-18 11:37:53 (308seconds)
# Processing ChamberID 9.0, session 24063
# Period: 2025-06-18 12:32:45 to 2025-06-18 12:37:53 (308seconds)
# Processing ChamberID 9.0, session 24064
# Period: 2025-06-18 13:32:45 to 2025-06-18 13:37:53 (308seconds)
# Processing ChamberID 9.0, session 24065
# Period: 2025-06-18 14:32:45 to 2025-06-18 14:37:53 (308seconds)
# Processing ChamberID 9.0, session 24066
# Period: 2025-06-18 15:32:45 to 2025-06-18 15:37:53 (308seconds)
# Processing ChamberID 9.0, session 24067
# Period: 2025-06-18 16:32:08 to 2025-06-18 16:37:16 (308seconds)
# Processing ChamberID 9.0, session 24068
# Period: 2025-06-18 17:32:08 to 2025-06-18 17:37:16 (308seconds)
# Processing ChamberID 9.0, session 24069
# Period: 2025-06-18 18:32:08 to 2025-06-18 18:37:16 (308seconds)
# Processing ChamberID 9.0, session 24070
# Period: 2025-06-18 19:32:08 to 2025-06-18 19:37:16 (308seconds)
# Processing ChamberID 9.0, session 24071
# Period: 2025-06-18 20:31:35 to 2025-06-18 20:36:43 (308seconds)
# Processing ChamberID 9.0, session 24072
# Period: 2025-06-18 21:31:35 to 2025-06-18 21:36:43 (308seconds)
# Processing ChamberID 9.0, session 24073
# Period: 2025-06-18 22:31:35 to 2025-06-18 22:36:43 (308seconds)
# Processing ChamberID 9.0, session 24074
# Period: 2025-06-18 23:31:35 to 2025-06-18 23:36:43 (308seconds)
# Processing ChamberID 9.0, session 24075
# Period: 2025-06-19 00:31:35 to 2025-06-19 00:36:43 (308seconds)
# Processing ChamberID 9.0, session 24076
# Period: 2025-06-19 01:31:35 to 2025-06-19 01:36:43 (308seconds)
# Processing ChamberID 9.0, session 24077
# Period: 2025-06-19 02:31:35 to 2025-06-19 02:36:43 (308seconds)
# Processing ChamberID 9.0, session 24078
# Period: 2025-06-19 03:31:35 to 2025-06-19 03:36:43 (308seconds)
# Processing ChamberID 9.0, session 24079
# Period: 2025-06-19 04:31:35 to 2025-06-19 04:36:43 (308seconds)
# Processing ChamberID 9.0, session 24080
# Period: 2025-06-19 05:31:35 to 2025-06-19 05:36:43 (308seconds)
# Processing ChamberID 9.0, session 24081
# Period: 2025-06-19 06:31:35 to 2025-06-19 06:36:43 (308seconds)
# Processing ChamberID 9.0, session 24082
# Period: 2025-06-19 07:31:35 to 2025-06-19 07:36:43 (308seconds)
# Processing ChamberID 9.0, session 24083
# Period: 2025-06-19 08:31:35 to 2025-06-19 08:36:43 (308seconds)
# Processing ChamberID 9.0, session 24084
# Period: 2025-06-19 09:31:35 to 2025-06-19 09:36:43 (308seconds)
# Processing ChamberID 9.0, session 24085
# Period: 2025-06-19 10:31:35 to 2025-06-19 10:36:43 (308seconds)
# Processing ChamberID 9.0, session 24086
# Period: 2025-06-19 11:31:35 to 2025-06-19 11:36:43 (308seconds)
# Processing ChamberID 9.0, session 24087
# Period: 2025-06-19 12:31:35 to 2025-06-19 12:36:43 (308seconds)
# Processing ChamberID 9.0, session 24088
# Period: 2025-06-19 13:31:35 to 2025-06-19 13:36:43 (308seconds)
# Processing ChamberID 9.0, session 24089
# Period: 2025-06-19 14:31:35 to 2025-06-19 14:36:43 (308seconds)
# Processing ChamberID 9.0, session 24090
# Period: 2025-06-19 15:31:35 to 2025-06-19 15:36:43 (308seconds)
# Processing ChamberID 9.0, session 24091
# Period: 2025-06-19 16:31:35 to 2025-06-19 16:36:43 (308seconds)
# Processing ChamberID 9.0, session 24092
# Period: 2025-06-19 17:31:35 to 2025-06-19 17:36:43 (308seconds)
# Processing ChamberID 9.0, session 24093
# Period: 2025-06-19 18:31:35 to 2025-06-19 18:36:43 (308seconds)
# Processing ChamberID 9.0, session 24094
# Period: 2025-06-19 19:31:35 to 2025-06-19 19:36:43 (308seconds)
# Processing ChamberID 9.0, session 24095
# Period: 2025-06-19 20:31:35 to 2025-06-19 20:36:43 (308seconds)
# Processing ChamberID 9.0, session 24096
# Period: 2025-06-19 21:31:35 to 2025-06-19 21:36:43 (308seconds)
# Processing ChamberID 9.0, session 24097
# Period: 2025-06-19 22:31:35 to 2025-06-19 22:36:43 (308seconds)
# Processing ChamberID 9.0, session 24098
# Period: 2025-06-19 23:31:35 to 2025-06-19 23:36:43 (308seconds)
# Processing ChamberID 9.0, session 24099
# Period: 2025-06-20 00:31:35 to 2025-06-20 00:36:43 (308seconds)
# Processing ChamberID 9.0, session 24100
# Period: 2025-06-20 01:31:35 to 2025-06-20 01:36:43 (308seconds)
# Processing ChamberID 9.0, session 24101
# Period: 2025-06-20 02:31:35 to 2025-06-20 02:36:43 (308seconds)
# Processing ChamberID 9.0, session 24102
# Period: 2025-06-20 03:31:35 to 2025-06-20 03:36:43 (308seconds)
# Processing ChamberID 9.0, session 24103
# Period: 2025-06-20 04:31:35 to 2025-06-20 04:36:43 (308seconds)
# Processing ChamberID 9.0, session 24104
# Period: 2025-06-20 05:31:35 to 2025-06-20 05:36:43 (308seconds)
# Processing ChamberID 9.0, session 24105
# Period: 2025-06-20 06:31:35 to 2025-06-20 06:36:43 (308seconds)
# Processing ChamberID 9.0, session 24106
# Period: 2025-06-20 07:31:35 to 2025-06-20 07:36:43 (308seconds)
# Processing ChamberID 9.0, session 24107
# Period: 2025-06-20 08:31:35 to 2025-06-20 08:36:43 (308seconds)
# Processing ChamberID 9.0, session 24108
# Period: 2025-06-20 09:31:35 to 2025-06-20 09:36:43 (308seconds)
# Processing ChamberID 9.0, session 24109
# Period: 2025-06-20 10:31:35 to 2025-06-20 10:36:43 (308seconds)
# Processing ChamberID 9.0, session 24110
# Period: 2025-06-20 11:31:35 to 2025-06-20 11:36:43 (308seconds)
# Processing ChamberID 9.0, session 24111
# Period: 2025-06-20 12:31:35 to 2025-06-20 12:36:43 (308seconds)
# Processing ChamberID 9.0, session 24112
# Period: 2025-06-20 13:31:35 to 2025-06-20 13:36:43 (308seconds)
# Processing ChamberID 9.0, session 24113
# Period: 2025-06-20 14:31:35 to 2025-06-20 14:36:43 (308seconds)
# Processing ChamberID 9.0, session 24114
# Period: 2025-06-20 15:31:35 to 2025-06-20 15:36:43 (308seconds)
# Processing ChamberID 9.0, session 24115
# Period: 2025-06-20 16:31:35 to 2025-06-20 16:36:43 (308seconds)
# Processing ChamberID 9.0, session 24116
# Period: 2025-06-20 17:31:35 to 2025-06-20 17:36:43 (308seconds)
# Processing ChamberID 9.0, session 24117
# Period: 2025-06-20 18:31:35 to 2025-06-20 18:36:43 (308seconds)
# Processing ChamberID 9.0, session 24118
# Period: 2025-06-20 19:31:35 to 2025-06-20 19:36:43 (308seconds)
# Processing ChamberID 9.0, session 24119
# Period: 2025-06-20 20:31:35 to 2025-06-20 20:36:43 (308seconds)
# Processing ChamberID 9.0, session 24120
# Period: 2025-06-20 21:31:35 to 2025-06-20 21:36:43 (308seconds)
# Processing ChamberID 9.0, session 24121
# Period: 2025-06-20 22:31:35 to 2025-06-20 22:36:43 (308seconds)
# Processing ChamberID 9.0, session 24122
# Period: 2025-06-20 23:31:35 to 2025-06-20 23:36:43 (308seconds)
# Processing ChamberID 9.0, session 24123
# Period: 2025-06-21 00:31:35 to 2025-06-21 00:36:43 (308seconds)
# Processing ChamberID 9.0, session 24124
# Period: 2025-06-21 01:31:35 to 2025-06-21 01:36:43 (308seconds)
# Processing ChamberID 9.0, session 24125
# Period: 2025-06-21 02:31:35 to 2025-06-21 02:36:43 (308seconds)
# Processing ChamberID 9.0, session 24126
# Period: 2025-06-21 03:31:35 to 2025-06-21 03:36:43 (308seconds)
# Processing ChamberID 9.0, session 24127
# Period: 2025-06-21 04:31:35 to 2025-06-21 04:36:43 (308seconds)
# Processing ChamberID 9.0, session 24128
# Period: 2025-06-21 05:31:35 to 2025-06-21 05:36:43 (308seconds)
# Processing ChamberID 9.0, session 24129
# Period: 2025-06-21 06:31:35 to 2025-06-21 06:36:43 (308seconds)
# Processing ChamberID 9.0, session 24130
# Period: 2025-06-21 07:31:35 to 2025-06-21 07:36:43 (308seconds)
# Processing ChamberID 9.0, session 24131
# Period: 2025-06-21 08:31:35 to 2025-06-21 08:36:43 (308seconds)
# Processing ChamberID 9.0, session 24132
# Period: 2025-06-21 09:31:35 to 2025-06-21 09:36:43 (308seconds)
# Processing ChamberID 9.0, session 24133
# Period: 2025-06-21 10:31:35 to 2025-06-21 10:36:43 (308seconds)
# Processing ChamberID 9.0, session 24134
# Period: 2025-06-21 11:31:35 to 2025-06-21 11:36:43 (308seconds)
# Processing ChamberID 9.0, session 24135
# Period: 2025-06-21 12:31:35 to 2025-06-21 12:36:43 (308seconds)
# Processing ChamberID 9.0, session 24136
# Period: 2025-06-21 13:31:35 to 2025-06-21 13:36:43 (308seconds)
# Processing ChamberID 9.0, session 24137
# Period: 2025-06-21 14:31:35 to 2025-06-21 14:36:43 (308seconds)
# Processing ChamberID 9.0, session 24138
# Period: 2025-06-21 15:31:35 to 2025-06-21 15:36:43 (308seconds)
# Processing ChamberID 9.0, session 24139
# Period: 2025-06-21 16:31:35 to 2025-06-21 16:36:43 (308seconds)
# Processing ChamberID 9.0, session 24140
# Period: 2025-06-21 17:31:35 to 2025-06-21 17:36:43 (308seconds)
# Processing ChamberID 9.0, session 24141
# Period: 2025-06-21 18:31:35 to 2025-06-21 18:36:43 (308seconds)
# Processing ChamberID 9.0, session 24142
# Period: 2025-06-21 19:31:35 to 2025-06-21 19:36:43 (308seconds)
# Processing ChamberID 9.0, session 24143
# Period: 2025-06-21 20:31:04 to 2025-06-21 20:36:12 (308seconds)
# Processing ChamberID 9.0, session 24144
# Period: 2025-06-21 21:31:04 to 2025-06-21 21:36:12 (308seconds)
# Processing ChamberID 9.0, session 24145
# Period: 2025-06-21 22:31:04 to 2025-06-21 22:36:12 (308seconds)
# Processing ChamberID 9.0, session 24146
# Period: 2025-06-21 23:31:04 to 2025-06-21 23:36:12 (308seconds)
# Processing ChamberID 9.0, session 24147
# Period: 2025-06-22 00:31:04 to 2025-06-22 00:36:12 (308seconds)
# Processing ChamberID 9.0, session 24148
# Period: 2025-06-22 01:31:04 to 2025-06-22 01:36:12 (308seconds)
# Processing ChamberID 9.0, session 24149
# Period: 2025-06-22 02:31:04 to 2025-06-22 02:36:12 (308seconds)
# Processing ChamberID 9.0, session 24150
# Period: 2025-06-22 03:31:04 to 2025-06-22 03:36:12 (308seconds)
# Processing ChamberID 9.0, session 24151
# Period: 2025-06-22 04:31:04 to 2025-06-22 04:36:12 (308seconds)
# Processing ChamberID 9.0, session 24152
# Period: 2025-06-22 05:31:04 to 2025-06-22 05:36:12 (308seconds)
# Processing ChamberID 9.0, session 24153
# Period: 2025-06-22 06:31:04 to 2025-06-22 06:36:12 (308seconds)
# Processing ChamberID 9.0, session 24154
# Period: 2025-06-22 07:31:04 to 2025-06-22 07:36:12 (308seconds)
# Processing ChamberID 9.0, session 24155
# Period: 2025-06-22 08:30:35 to 2025-06-22 08:35:43 (308seconds)
# Processing ChamberID 9.0, session 24156
# Period: 2025-06-22 09:30:35 to 2025-06-22 09:35:43 (308seconds)
# Processing ChamberID 9.0, session 24157
# Period: 2025-06-22 10:30:35 to 2025-06-22 10:35:43 (308seconds)
# Processing ChamberID 9.0, session 24158
# Period: 2025-06-22 11:30:35 to 2025-06-22 11:35:43 (308seconds)
# Processing ChamberID 9.0, session 24159
# Period: 2025-06-22 12:30:35 to 2025-06-22 12:35:43 (308seconds)
# Processing ChamberID 9.0, session 24160
# Period: 2025-06-22 13:30:35 to 2025-06-22 13:35:43 (308seconds)
# Processing ChamberID 9.0, session 24161
# Period: 2025-06-22 14:30:35 to 2025-06-22 14:35:43 (308seconds)
# Processing ChamberID 9.0, session 24162
# Period: 2025-06-22 15:30:35 to 2025-06-22 15:35:43 (308seconds)
# Processing ChamberID 9.0, session 24163
# Period: 2025-06-22 16:30:35 to 2025-06-22 16:35:43 (308seconds)
# Processing ChamberID 9.0, session 24164
# Period: 2025-06-22 17:30:35 to 2025-06-22 17:35:43 (308seconds)
# Processing ChamberID 9.0, session 24165
# Period: 2025-06-22 18:30:35 to 2025-06-22 18:35:43 (308seconds)
# Processing ChamberID 9.0, session 24166
# Period: 2025-06-22 19:30:35 to 2025-06-22 19:35:43 (308seconds)
# Processing ChamberID 9.0, session 24167
# Period: 2025-06-22 20:30:01 to 2025-06-22 20:35:09 (308seconds)
# Processing ChamberID 9.0, session 24168
# Period: 2025-06-22 21:30:01 to 2025-06-22 21:35:09 (308seconds)
# Processing ChamberID 9.0, session 24169
# Period: 2025-06-22 22:30:01 to 2025-06-22 22:35:09 (308seconds)
# Processing ChamberID 9.0, session 24170
# Period: 2025-06-22 23:30:01 to 2025-06-22 23:35:09 (308seconds)
# Processing ChamberID 9.0, session 24171
# Period: 2025-06-23 00:32:45 to 2025-06-23 00:37:53 (308seconds)
# Processing ChamberID 9.0, session 24172
# Period: 2025-06-23 01:32:45 to 2025-06-23 01:37:53 (308seconds)
# Processing ChamberID 9.0, session 24173
# Period: 2025-06-23 02:32:45 to 2025-06-23 02:37:53 (308seconds)
# Processing ChamberID 9.0, session 24174
# Period: 2025-06-23 03:32:45 to 2025-06-23 03:37:53 (308seconds)
# Processing ChamberID 9.0, session 24175
# Period: 2025-06-23 04:32:45 to 2025-06-23 04:37:53 (308seconds)
# Processing ChamberID 9.0, session 24176
# Period: 2025-06-23 05:32:45 to 2025-06-23 05:37:53 (308seconds)
# Processing ChamberID 9.0, session 24177
# Period: 2025-06-23 06:32:45 to 2025-06-23 06:37:53 (308seconds)
# Processing ChamberID 9.0, session 24178
# Period: 2025-06-23 07:32:45 to 2025-06-23 07:37:53 (308seconds)
# Processing ChamberID 9.0, session 24179
# Period: 2025-06-23 08:32:45 to 2025-06-23 08:37:53 (308seconds)
# Processing ChamberID 9.0, session 24180
# Period: 2025-06-23 09:32:45 to 2025-06-23 09:37:53 (308seconds)
# Processing ChamberID 9.0, session 24181
# Period: 2025-06-23 10:32:45 to 2025-06-23 10:37:53 (308seconds)
# Processing ChamberID 9.0, session 24182
# Period: 2025-06-23 11:32:45 to 2025-06-23 11:37:53 (308seconds)
# Processing ChamberID 9.0, session 24183
# Period: 2025-06-23 12:32:43 to 2025-06-23 12:37:51 (308seconds)
# Processing ChamberID 9.0, session 24184
# Period: 2025-06-23 13:32:43 to 2025-06-23 13:37:51 (308seconds)
# Processing ChamberID 9.0, session 24185
# Period: 2025-06-23 14:32:43 to 2025-06-23 14:37:51 (308seconds)
# Processing ChamberID 9.0, session 24186
# Period: 2025-06-23 15:32:43 to 2025-06-23 15:37:51 (308seconds)
# Processing ChamberID 9.0, session 24187
# Period: 2025-06-23 16:32:43 to 2025-06-23 16:37:51 (308seconds)
# Processing ChamberID 9.0, session 24188
# Period: 2025-06-23 17:32:43 to 2025-06-23 17:37:51 (308seconds)
# Processing ChamberID 9.0, session 24189
# Period: 2025-06-23 18:32:43 to 2025-06-23 18:37:51 (308seconds)
# Processing ChamberID 9.0, session 24190
# Period: 2025-06-23 19:32:43 to 2025-06-23 19:37:51 (308seconds)
# Processing ChamberID 9.0, session 24191
# Period: 2025-06-23 20:32:43 to 2025-06-23 20:37:51 (308seconds)
# Processing ChamberID 9.0, session 24192
# Period: 2025-06-23 21:32:43 to 2025-06-23 21:37:51 (308seconds)
# Processing ChamberID 9.0, session 24193
# Period: 2025-06-23 22:32:43 to 2025-06-23 22:37:51 (308seconds)
# Processing ChamberID 9.0, session 24194
# Period: 2025-06-23 23:32:43 to 2025-06-23 23:37:51 (308seconds)
# Total sessions processed: 24194
